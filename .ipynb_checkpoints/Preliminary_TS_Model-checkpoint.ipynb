# %%
from Almanac.Data import get_weather_data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = get_weather_data('Chicago, IL, 60601, US','2018-01-01','2023-01-01')

# %%
df.plot(y=['tavg','tmin','tmax'])
# Out:
# <Axes: xlabel='time'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
r = seasonal_decompose(df['tmin'],period=int(365/4),model='add')

# %%
fig, ax = plt.subplots(nrows=4,ncols=1,figsize=(12,8))
ax[0].plot(df['tmin'])
ax[1].plot(r.trend)
ax[2].plot(r.seasonal)
ax[3].scatter(x=r.resid.index,y=r.resid)

ax[0].set_title('tmin')
ax[1].set_title('Trend')
ax[2].set_title('Seasonal')
ax[3].set_title('Residual')

fig.tight_layout()

# %%
from statsmodels.tsa.filters.hp_filter import hpfilter

# %%
cyc,trend = hpfilter(df['tmin'],lamb=13322500)

# %%
fig2,ax2 = plt.subplots(nrows=3,ncols=1,figsize=(12,8))
ax2[0].plot(df['tmin'])
ax2[1].plot(trend)
ax2[2].plot(cyc)

ax2[0].set_title('tmin')
ax2[1].set_title('Trend')
ax2[2].set_title('Seasonal')

plt.subplots_adjust(hspace=0.4)

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
df['TEFit_tmin'] = ExponentialSmoothing(df['tmin'],trend='add',seasonal='add',seasonal_periods=365).fit().fittedvalues

# %%
df.plot(y=['tmin','TEFit_tmin'])
# Out:
# <Axes: xlabel='time'>

# %%
fitted_model = ExponentialSmoothing(df['tmin'].loc[:'2022-01-01'],trend='add',seasonal='add',seasonal_periods=365).fit()

# %%
pred = fitted_model.forecast(365)

# %%
df['tmin'].loc[:'2022-01-01'].plot(figsize=(12,5),label='TRAIN')
df['tmin'].loc['2022-01-01':].plot(label='TEST')
# Out:
# <Axes: xlabel='time'>

# %%
df['tmin'].loc[:'2022-01-01'].plot(figsize=(12,5),label='TRAIN',legend=True)
df['tmin'].loc['2022-01-01':].plot(label='TEST',legend=True)
pred.plot(label='PREDICTION',legend=True)
# fitted_model.fittedvalues.plot()
# Out:
# <Axes: xlabel='time'>

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(df['tmin'].loc['2022-01-01':][1:],pred))
# Out:
# 8.326389364138715

# %%
df['tmin'].describe()
# Out:
# count    1827.000000
# mean        7.124904
# std        10.852440
# min       -30.000000
# 25%        -1.100000
# 50%         6.100000
# 75%        17.200000
# max        28.300000
# Name: tmin, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1827 entries, 2018-01-01 to 2023-01-01
# Freq: D
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tavg        1827 non-null   float64
#  1   tmin        1827 non-null   float64
#  2   tmax        1827 non-null   float64
#  3   prcp        1827 non-null   float64
#  4   snow        1827 non-null   float64
#  5   wdir        1791 non-null   float64
#  6   wspd        1827 non-null   float64
#  7   wpgt        0 non-null      float64
#  8   pres        1816 non-null   float64
#  9   tsun        0 non-null      float64
#  10  TEFit_tmin  1827 non-null   float64
# dtypes: float64(11)
# memory usage: 235.8 KB
